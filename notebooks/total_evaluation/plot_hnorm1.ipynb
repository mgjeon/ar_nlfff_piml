# %%
import pandas as pd
import json
import argparse
from pathlib import Path

from rtmag.test.post import Metrics

configs = argparse.Namespace()

with open("/home/usr/workspace/ar_nlfff_piml/configs/test/uno_pi_cc_hnorm_1_unit_aug_ccc_square_12673.json") as config:
    info = json.load(config)
    for key, value in info.items():
        configs.__dict__[key] = value


result_path = Path(configs.result_path)

result_csv = result_path / "real_time.csv"

f = pd.read_csv(result_csv)
m = Metrics(f,
            title=configs.metrics["title"],
            energy_ylim=configs.metrics["energy_ylim"],
            free_energy_ylim=configs.metrics["free_energy_ylim"],
            metrics_ylim=configs.metrics["metrics_ylim"],
            error_ylim=configs.metrics["error_ylim"],
            eps_ylim=configs.metrics["eps_ylim"],
            hour=configs.metrics["hour"])
m.print()

with open(result_path / "metrics.txt", "w") as f:
    df = m.df
    eps_mean = m.eps.mean()
    c_vec_mean = df['C_vec'].mean()
    c_cs_mean = df['C_cs'].mean()
    e_n_mean = df["E_n_prime"].mean()
    e_m_mean = df["E_m_prime"].mean()
    l2_err_mean = df['l2_err'].mean()
    f.write(f"avg C_vec        : {c_vec_mean:.2f}\n")
    f.write(f"avg C_cs         : {c_cs_mean:.2f}\n")
    f.write(f"avg E_n_prime    : {e_n_mean:.2f}\n")
    f.write(f"avg E_m_prime    : {e_m_mean:.2f}\n")
    f.write(f"avg eps          : {eps_mean:.2f}\n")
    f.write(f"avg l2_err       : {l2_err_mean:.2f}\n")

m.plot(result_path)
# Out:
# avg C_vec     : 0.96
# avg C_cs      : 0.78
# avg E_n_prime : 0.57
# avg E_m_prime : 0.10
# avg eps       : 1.03
# avg l2_err    : 0.29
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:85: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.tight_layout()
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:86: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.savefig(result_path / 'energy.png', dpi=600)
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:125: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.tight_layout()
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:126: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.savefig(result_path / 'free_energy.png', dpi=600)
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:167: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.tight_layout()
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:168: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.savefig(result_path / 'metrics.png', dpi=600)
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:203: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.tight_layout()
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:204: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.savefig(result_path / 'error.png', dpi=600)
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:237: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.tight_layout()
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:238: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.savefig(result_path / 'eps.png', dpi=600)
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:269: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.tight_layout()
# /home/usr/workspace/ar_nlfff_piml/rtmag/test/post.py:270: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   plt.savefig(result_path / 'b_norm.png', dpi=600)
# /home/usr/miniforge3/envs/rtmag/lib/python3.11/site-packages/IPython/core/pylabtools.py:152: UserWarning: AutoDateLocator was unable to pick an appropriate interval for this date range. It may be necessary to add an interval value to the AutoDateLocator's intervald dictionary. Defaulting to 3.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import numpy as np

# %%
(df['b_norm']/np.max(df['b_norm'])).plot()
df['eps'].plot()
# Out:
# <Axes: >
