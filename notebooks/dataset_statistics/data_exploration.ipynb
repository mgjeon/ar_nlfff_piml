# %%
import numpy as np
import matplotlib.pyplot as plt
from pathlib import Path

# %%
idx = 241

data_path = Path('F:/isee_dataset/12673/input/').glob('*.npz')
data_path = sorted(data_path)

label_path = Path('F:/isee_dataset/12673/label/').glob('*.npz')
label_path = sorted(label_path)

print(data_path[idx].name)
print(label_path[idx].name)
# Out:
# input_12673_20170906_090000.npz
# label_12673_20170906_090000.npz

# %%
labels = np.load(label_path[idx])

# %%
labels.keys()
# Out:
# KeysView(NpzFile 'F:\\isee_dataset\\12673\\label\\label_12673_20170906_090000.npz' with keys: label, pot, x, y, z)

# %%
b = labels['label']
b = b[:, :-1, :-1, :-1]
b.shape
# Out:
# (3, 512, 256, 256)

# %%
bx = b[0]
by = b[1]
bz = b[2]

bz.shape
# Out:
# (512, 256, 256)

# %%
plt.hist(bz[:, :, 0].flatten(), alpha=0.5)
plt.hist(bz[:, :, 50].flatten(), alpha=0.5)
plt.show()

# %%
plt.hist(bz[:, :, 50].flatten(), alpha=0.5)
plt.hist(bz[:, :, 100].flatten(), alpha=0.5)
plt.show()

# %%
plt.hist(bz[:, :, 100].flatten(), alpha=0.5)
plt.hist(bz[:, :, 150].flatten(), alpha=0.5)
plt.show()

# %%
plt.hist(bz[:, :, 150].flatten(), alpha=0.5)
plt.hist(bz[:, :, 200].flatten(), alpha=0.5)
plt.show()

# %%
plt.hist(bz[:, :, 200].flatten(), alpha=0.5)
plt.hist(bz[:, :, 250].flatten(), alpha=0.5)
plt.show()
