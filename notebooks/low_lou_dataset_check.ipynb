# %%
from rtmag.dataset.dataset_hnorm_unit_lowlou import LowLouDataset_Multiple_Hnorm_Unit, LowLouDataset_Hnorm_Unit
import matplotlib.pyplot as plt
import numpy as np

# %%
train_datapath = '/mnt/f/low_lou/train'
test_datapath = '/mnt/f/low_lou/test'

# %%
b_test = np.load(test_datapath + '/case1.npz')['b'].transpose(3, 0, 1, 2)
b_test.shape
# Out:
# (3, 64, 64, 64)

# %%
plt.imshow(b_test[2, :, :, 0], vmin=-100, vmax=100)
plt.colorbar()

# %%
train_dataset = LowLouDataset_Multiple_Hnorm_Unit(dataset_path=train_datapath, b_norm=200)
test_dataset = LowLouDataset_Hnorm_Unit(data_path=test_datapath, b_norm=200)

# %%
batch = test_dataset[0]

# %%
b_batch = batch['label'].numpy()
divi = (200 / np.arange(1, 64 + 1)).reshape(1, 1, 1, -1).astype(np.float32)
b_batch = b_batch * divi
b_batch.shape
# Out:
# (3, 64, 64, 64)

# %%
plt.imshow(b_batch[2, :, :, 0], vmin=-100, vmax=100)
plt.colorbar()

# %%
b_test.transpose(3, 0, 1, 2).shape

# %%
(batch['label']*divi).shape

# %%
np.allclose(b_test.transpose(3, 0, 1, 2), batch['label']*divi)

# %%
plt.imshow((batch['input']*200)[2, :, :, 0], vmin=-100, vmax=100)
plt.colorbar()
