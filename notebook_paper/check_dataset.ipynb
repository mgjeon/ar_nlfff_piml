# %%
import matplotlib.pyplot as plt
from rtmag.dataset.dataset_hnorm_unit_aug import ISEEDataset_Hnorm_Unit_Aug, ISEEDataset_Multiple_Hnorm_Unit_Aug
from rtmag.dataset.dataset_hnorm_unit_aug_potential import ISEEDataset_Hnorm_Unit_Aug_Potential, ISEEDataset_Multiple_Hnorm_Unit_Aug_Potential

# %%
dataset = ISEEDataset_Multiple_Hnorm_Unit_Aug_Potential("/mnt/f/isee_dataset", 2500, ["11158", "12673"])

# %%
batch = dataset[0]

# %%
inputs = batch["input"]
labels = batch["label"]

# %%
inputs.shape
# Out:
# torch.Size([3, 512, 256, 1])

# %%
labels.shape
# Out:
# torch.Size([3, 512, 256, 256])

# %%
plt.imshow(inputs[0, :, :, 0].T, origin="lower", cmap="gray")
plt.colorbar()

# %%
plt.imshow(labels[0, :, :, 0].T, origin="lower", cmap="gray")
plt.colorbar()

# %%
dataset = ISEEDataset_Hnorm_Unit_Aug_Potential("/mnt/f/isee_dataset/11158", 2500)

# %%
batch = dataset[0]

# %%
inputs = batch["input"]
labels = batch["label"]

# %%
inputs.shape
# Out:
# torch.Size([3, 512, 256, 1])

# %%
labels.shape
# Out:
# torch.Size([3, 512, 256, 256])

# %%
plt.imshow(inputs[0, :, :, 0].T, origin="lower", cmap="gray")
plt.colorbar()

# %%
plt.imshow(labels[0, :, :, 0].T, origin="lower", cmap="gray")
plt.colorbar()

# %%
dataset = ISEEDataset_Multiple_Hnorm_Unit_Aug("/mnt/f/isee_dataset", 2500, ["11158", "12673"])

# %%
batch = dataset[0]

# %%
inputs = batch["input"]
labels = batch["label"]

# %%
inputs.shape
# Out:
# torch.Size([3, 512, 256, 1])

# %%
labels.shape
# Out:
# torch.Size([3, 512, 256, 256])

# %%
plt.imshow(inputs[0, :, :, 0].T, origin="lower", cmap="gray")
plt.colorbar()

# %%
plt.imshow(labels[0, :, :, 0].T, origin="lower", cmap="gray")
plt.colorbar()

# %%
dataset = ISEEDataset_Hnorm_Unit_Aug("/mnt/f/isee_dataset/11158", 2500)

# %%
batch = dataset[0]

# %%
inputs = batch["input"]
labels = batch["label"]

# %%
inputs.shape
# Out:
# torch.Size([3, 512, 256, 1])

# %%
labels.shape
# Out:
# torch.Size([3, 512, 256, 256])

# %%
plt.imshow(inputs[0, :, :, 0].T, origin="lower", cmap="gray")
plt.colorbar()

# %%
plt.imshow(labels[0, :, :, 0].T, origin="lower", cmap="gray")
plt.colorbar()
